# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv('H1Bprocessed.csv')
# Out:
# C:\Users\varun\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (16,17,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
dfwage=pd.read_csv('H1Bprocessed.csv')

# %%
df = df.filter(['EMPLOYER_NAME_BIN' ,                      
'EMPLOYER_CITY_BIN',                       
'H1B_DEPENDENT',                           
'NAICS_CODE_BIN',                          
'Visa_duration_bin',                  
'AGENT_ATTORNEY_CITY_BIN',                 
'PREVAILING_WAGE_BIN',                     
'SOC_REVISED_CODE',                      
'PW_UNIT_OF_PAY',                         
'PW_SOURCE',                              
'WAGE_UNIT_OF_PAY',                     
'EMPLOYER_STATE_BIN',                       
'WORKSITE_STATE' ,                         
'PW_WAGE_LEVEL',                           
'WORKSITE_COUNTY_BIN',
'AGENT_ATTORNEY_STATE_BIN',                
'AMENDED_PETITION_BIN',
'AGENT_REPRESENTING_EMPLOYER',             
'FULL_TIME_POSITION',                      
'WORKSITE_STATE_BIN',
'NEW_EMPLOYMENT_BIN' ,                          
'CHANGE_PREVIOUS_EMPLOYMENT_BIN',               
'WORKSITE_CITY_BIN','Target','JOB_TITLE' 
], axis=1)

# %%
df
# Out:
#        EMPLOYER_NAME_BIN EMPLOYER_CITY_BIN H1B_DEPENDENT NAICS_CODE_BIN  \
# 0                   Bin5              Bin7             N         Others
# 1                   Bin2              Bin5             N           Bin1
# 2                 Others              Bin5             N           Bin3
# 3                   Bin5              Bin7             Y           Bin3
# 4                 Others              Bin7             Y           Bin3
# 5                 Others              Bin5             Y           Bin3
# 6                 Others              Bin4             Y           Bin3
# 7                   Bin5              Bin7             Y           Bin2
# 8                 Others              Bin4           NaN           Bin3
# 9                 Others              Bin5             Y           Bin3
# 10                Others              Bin4             Y           Bin3
# 11                Others            Others             N         Others
# 12                  Bin3              Bin6             Y           Bin3
# 13                  Bin4              Bin7             Y           Bin3
# 14                Others            Others             N         Others
# 15                  Bin4              Bin7             Y           Bin3
# 16                Others              Bin5             N         Others
# 17                Others              Bin1             N         Others
# 18                Others            Others             N           Bin2
# 19                Others              Bin2             N         Others
# 20                Others            Others             N           Bin1
# 21                Others            Others             N         Others
# 22                Others              Bin2             N           Bin1
# 23                Others              Bin6             N         Others
# 24                Others              Bin3             N           Bin1
# 25                Others              Bin6             Y           Bin3
# 26                Others              Bin4             N         Others
# 27                  Bin1              Bin1             N           Bin3
# 28                Others              Bin1             N           Bin2
# 29                  Bin1              Bin2             N           Bin2
# ...                  ...               ...           ...            ...
# 633050            Others              Bin5             Y           Bin3
# 633051            Others              Bin2             N         Others
# 633052            Others              Bin7             Y           Bin3
# 633053              Bin4              Bin6             Y           Bin3
# 633054            Others            Others             N           Bin2
# 633055            Others              Bin1             N           Bin3
# 633056              Bin2              Bin4             N           Bin2
# 633057              Bin1              Bin4             N           Bin1
# 633058            Others              Bin3             N           Bin1
# 633059              Bin2              Bin3             N           Bin2
# 633060              Bin4              Bin7             Y           Bin3
# 633061            Others              Bin1             N           Bin2
# 633062              Bin5              Bin7             Y           Bin2
# 633063            Others              Bin7             N         Others
# 633064            Others              Bin4             N         Others
# 633065            Others            Others             N         Others
# 633066            Others              Bin5             Y           Bin3
# 633067            Others            Others             Y           Bin3
# 633068              Bin4              Bin7             Y           Bin3
# 633069            Others              Bin6             Y           Bin2
# 633070            Others              Bin5             N           Bin3
# 633071              Bin2              Bin6             Y           Bin3
# 633072              Bin5              Bin6             Y           Bin3
# 633073              Bin2            Others             Y           Bin3
# 633074            Others              Bin1             N           Bin2
# 633075            Others              Bin5             Y           Bin1
# 633076            Others            Others             N         Others
# 633077            Others            Others           NaN         Others
# 633078              Bin2              Bin4             N           Bin2
# 633079              Bin5              Bin7             N         Others
#
#        Visa_duration_bin AGENT_ATTORNEY_CITY_BIN PREVAILING_WAGE_BIN  \
# 0                2-3 yrs                  Others                Bin4
# 1                2-3 yrs                    Bin3                Bin4
# 2                2-3 yrs                  Others                Bin4
# 3                2-3 yrs                    Bin4                Bin4
# 4                2-3 yrs                    Bin5                Bin4
# 5                2-3 yrs                    Bin1                Bin4
# 6                   <1yr                  Others                Bin4
# 7                2-3 yrs                  Others                Bin4
# 8                1-2 yrs                  Others                Bin4
# 9                2-3 yrs                    Bin4                Bin4
# 10               2-3 yrs                  Others                Bin4
# 11               2-3 yrs                    Bin4                Bin4
# 12               2-3 yrs                    Bin4                Bin4
# 13               2-3 yrs                  Others                Bin4
# 14               2-3 yrs                  Others                Bin4
# 15               2-3 yrs                  Others                Bin4
# 16               2-3 yrs                    Bin4                Bin4
# 17               2-3 yrs                  Others                Bin3
# 18               2-3 yrs                  Others                Bin2
# 19               2-3 yrs                    Bin2                Bin3
# 20               2-3 yrs                    Bin4                Bin4
# 21               2-3 yrs                    Bin1                Bin4
# 22               2-3 yrs                    Bin1                Bin5
# 23               2-3 yrs                    Bin4                Bin4
# 24               2-3 yrs                    Bin2                Bin4
# 25               2-3 yrs                    Bin4                Bin4
# 26               2-3 yrs                    Bin4                Bin4
# 27               2-3 yrs                    Bin1                Bin4
# 28               2-3 yrs                    Bin2                Bin3
# 29               2-3 yrs                    Bin1                Bin4
# ...                  ...                     ...                 ...
# 633050           2-3 yrs                    Bin1                Bin4
# 633051           2-3 yrs                    Bin2                Bin4
# 633052           2-3 yrs                  Others                Bin4
# 633053           2-3 yrs                  Others                Bin4
# 633054           2-3 yrs                  Others                Bin4
# 633055           2-3 yrs                  Others                Bin3
# 633056           1-2 yrs                  Others                Bin4
# 633057           2-3 yrs                    Bin3                Bin4
# 633058           2-3 yrs                    Bin5                Bin5
# 633059           2-3 yrs                    Bin3                Bin4
# 633060           2-3 yrs                    Bin4                Bin3
# 633061           2-3 yrs                    Bin4                Bin4
# 633062           2-3 yrs                  Others                Bin4
# 633063           2-3 yrs                    Bin1                Bin2
# 633064           2-3 yrs                    Bin4                Bin4
# 633065           2-3 yrs                    Bin2                Bin3
# 633066           2-3 yrs                  Others                Bin4
# 633067           2-3 yrs                    Bin5                Bin4
# 633068           2-3 yrs                  Others                Bin4
# 633069           2-3 yrs                    Bin5                Bin4
# 633070           2-3 yrs                    Bin5                Bin3
# 633071           2-3 yrs                  Others                Bin4
# 633072           2-3 yrs                  Others                Bin5
# 633073           2-3 yrs                    Bin4                Bin4
# 633074           2-3 yrs                  Others                Bin4
# 633075           2-3 yrs                  Others                Bin4
# 633076           2-3 yrs                    Bin4                Bin4
# 633077              <1yr                    Bin1                Bin4
# 633078           1-2 yrs                  Others                Bin4
# 633079           2-3 yrs                  Others                Bin5
#
#        SOC_REVISED_CODE PW_UNIT_OF_PAY PW_SOURCE  ...  \
# 0                    15           Year       OES  ...
# 1                    13           Year       OES  ...
# 2                    15           Year       OES  ...
# 3                    15           Year       OES  ...
# 4                    15           Year       OES  ...
# 5                    15           Year     Other  ...
# 6                    15           Year     Other  ...
# 7                    15           Year       OES  ...
# 8                    15           Year       OES  ...
# 9                    15           Year       OES  ...
# 10                   15           Year       OES  ...
# 11                   17           Year       OES  ...
# 12                   15           Year       OES  ...
# 13                   15           Year       OES  ...
# 14                   15           Hour       OES  ...
# 15                   15           Year       OES  ...
# 16                   15           Year     Other  ...
# 17                   13           Year     Other  ...
# 18                   13           Hour       OES  ...
# 19                   17           Hour       OES  ...
# 20                   19           Year     Other  ...
# 21                   13           Year     Other  ...
# 22                   15           Year     Other  ...
# 23                   15           Year     Other  ...
# 24                   19           Year     Other  ...
# 25                   15           Year       OES  ...
# 26                   15           Year       OES  ...
# 27                   15           Year     Other  ...
# 28                   13           Year     Other  ...
# 29                   15           Year     Other  ...
# ...                 ...            ...       ...  ...
# 633050              NaN           Year       OES  ...
# 633051              NaN           Year       OES  ...
# 633052              NaN           Hour       OES  ...
# 633053              NaN           Year       OES  ...
# 633054              NaN           Year       OES  ...
# 633055              NaN           Year       OES  ...
# 633056              NaN           Year       OES  ...
# 633057              NaN           Year       OES  ...
# 633058              NaN           Year       OES  ...
# 633059              NaN           Year       OES  ...
# 633060              NaN           Year       OES  ...
# 633061              NaN           Year       OES  ...
# 633062              NaN           Year       OES  ...
# 633063              NaN           Year     Other  ...
# 633064              NaN           Year       OES  ...
# 633065              NaN           Year       OES  ...
# 633066              NaN           Year     Other  ...
# 633067              NaN           Year       OES  ...
# 633068              NaN           Year       OES  ...
# 633069              NaN           Year       OES  ...
# 633070              NaN           Year       OES  ...
# 633071              NaN           Year     Other  ...
# 633072              NaN           Year       OES  ...
# 633073              NaN           Year     Other  ...
# 633074              NaN           Year     Other  ...
# 633075              NaN           Year       OES  ...
# 633076              NaN           Year       OES  ...
# 633077              NaN           Year       OES  ...
# 633078              NaN           Year       OES  ...
# 633079              NaN           Year       OES  ...
#
#        AGENT_ATTORNEY_STATE_BIN AMENDED_PETITION_BIN  \
# 0                        Others                    0
# 1                        Others                    0
# 2                        Others                    0
# 3                        Others                    0
# 4                          Bin4                    1
# 5                          Bin1                    1
# 6                        Others                    0
# 7                        Others                    0
# 8                        Others                    0
# 9                          Bin4                    0
# 10                       Others                    0
# 11                         Bin2                    0
# 12                       Others                    0
# 13                       Others                    0
# 14                       Others                    0
# 15                       Others                    0
# 16                         Bin1                    0
# 17                         Bin5                    0
# 18                         Bin3                    0
# 19                         Bin3                    0
# 20                         Bin3                    0
# 21                         Bin4                    0
# 22                         Bin1                    0
# 23                         Bin3                    0
# 24                         Bin3                   >1
# 25                         Bin4                   >1
# 26                         Bin5                    0
# 27                         Bin1                    0
# 28                         Bin2                    0
# 29                         Bin1                    0
# ...                         ...                  ...
# 633050                     Bin1                    0
# 633051                     Bin2                    0
# 633052                   Others                    1
# 633053                   Others                    1
# 633054                   Others                    0
# 633055                     Bin4                    0
# 633056                   Others                    0
# 633057                   Others                    0
# 633058                     Bin4                    0
# 633059                     Bin5                    0
# 633060                     Bin4                    0
# 633061                   Others                    0
# 633062                   Others                    0
# 633063                     Bin1                    0
# 633064                     Bin2                    0
# 633065                     Bin2                    0
# 633066                   Others                    1
# 633067                     Bin5                    1
# 633068                   Others                    0
# 633069                     Bin4                    1
# 633070                     Bin4                    1
# 633071                   Others                    1
# 633072                   Others                    1
# 633073                     Bin5                    1
# 633074                   Others                    0
# 633075                   Others                    0
# 633076                     Bin5                    0
# 633077                     Bin1                    0
# 633078                   Others                    0
# 633079                   Others                    0
#
#        AGENT_REPRESENTING_EMPLOYER FULL_TIME_POSITION WORKSITE_STATE_BIN  \
# 0                                N                  Y               bin5
# 1                                Y                  Y               Bin1
# 2                                N                  Y               Bin2
# 3                                Y                  Y             Others
# 4                                Y                  Y             Others
# 5                                Y                  Y               Bin7
# 6                                N                  Y               Bin7
# 7                                N                  Y             Others
# 8                                N                  Y               bin4
# 9                                Y                  Y               Bin7
# 10                               N                  Y               Bin1
# 11                               Y                  Y               bin6
# 12                               Y                  Y               Bin3
# 13                               N                  Y             Others
# 14                               N                  Y             Others
# 15                               N                  Y             Others
# 16                               Y                  Y               Bin2
# 17                               Y                  Y               bin6
# 18                               Y                  N               Bin1
# 19                               Y                  Y             Others
# 20                               Y                  Y               Bin1
# 21                               Y                  Y               bin4
# 22                               Y                  Y               Bin1
# 23                               Y                  Y               Bin1
# 24                               Y                  Y               Bin1
# 25                               Y                  Y               bin5
# 26                               Y                  Y             Others
# 27                               Y                  Y             Others
# 28                               Y                  Y               bin4
# 29                               Y                  Y               Bin1
# ...                            ...                ...                ...
# 633050                           Y                  Y               Bin2
# 633051                           Y                  Y               bin5
# 633052                           N                  Y               Bin7
# 633053                           N                  Y             Others
# 633054                           Y                  Y             Others
# 633055                           Y                  Y               Bin3
# 633056                           N                  Y             Others
# 633057                           Y                  Y             Others
# 633058                           Y                  Y             Others
# 633059                           Y                  Y               bin5
# 633060                           Y                  Y               Bin2
# 633061                           Y                  Y             Others
# 633062                           N                  Y             Others
# 633063                           Y                  Y               Bin2
# 633064                           Y                  Y               bin6
# 633065                           Y                  Y               Bin1
# 633066                           N                  Y               Bin3
# 633067                           Y                  Y             Others
# 633068                           N                  Y             Others
# 633069                           Y                  Y               Bin7
# 633070                           Y                  Y             Others
# 633071                           N                  Y             Others
# 633072                           N                  Y             Others
# 633073                           Y                  Y             Others
# 633074                           N                  Y               Bin3
# 633075                           N                  Y               Bin2
# 633076                           Y                  Y             Others
# 633077                           Y                  Y               Bin7
# 633078                           N                  Y             Others
# 633079                           N                  Y               bin5
#
#        NEW_EMPLOYMENT_BIN CHANGE_PREVIOUS_EMPLOYMENT_BIN WORKSITE_CITY_BIN  \
# 0                       0                              0            Others
# 1                       0                              0            Others
# 2                       0                              0              Bin2
# 3                      >1                              0            Others
# 4                       0                              0              Bin4
# 5                       0                              0            Others
# 6                       0                              0              Bin3
# 7                       0                              0            Others
# 8                       0                              0              Bin3
# 9                       0                              0              Bin3
# 10                      0                              1            Others
# 11                      0                              1            Others
# 12                      0                              0              Bin4
# 13                      1                              0            Others
# 14                      1                              0            Others
# 15                      1                              0            Others
# 16                      1                              0              Bin2
# 17                      0                              0              Bin2
# 18                      1                              0            Others
# 19                      1                              0            Others
# 20                      1                              0            Others
# 21                      1                              0              Bin3
# 22                      1                              0            Others
# 23                      1                              0            Others
# 24                     >1                             >1            Others
# 25                     >1                             >1              Bin1
# 26                     >1                              0              Bin3
# 27                      1                              0              Bin2
# 28                      1                              0              Bin3
# 29                      1                              0            Others
# ...                   ...                            ...               ...
# 633050                  0                              0              Bin2
# 633051                  0                              0              Bin1
# 633052                  1                              1              Bin3
# 633053                  0                              0            Others
# 633054                  1                              0              Bin4
# 633055                  1                              0            Others
# 633056                  0                              0            Others
# 633057                  0                              0              Bin2
# 633058                  0                              1            Others
# 633059                  0                              0            Others
# 633060                  0                              0            Others
# 633061                  1                              0              Bin3
# 633062                  1                              0            Others
# 633063                  1                              0            Others
# 633064                  0                              0            Others
# 633065                  1                              0            Others
# 633066                  0                              0            Others
# 633067                  0                              0            Others
# 633068                  1                              0              Bin4
# 633069                  0                              0              Bin3
# 633070                  0                              0            Others
# 633071                  0                              0              Bin3
# 633072                  0                              0            Others
# 633073                  0                              0              Bin4
# 633074                  1                              0            Others
# 633075                  1                              0              Bin2
# 633076                  1                              0            Others
# 633077                  1                              0            Others
# 633078                  1                              0              Bin4
# 633079                  1                              0            Others
#
#        Target                                          JOB_TITLE
# 0         0.0                                  SOFTWARE ENGINEER
# 1         0.0                                         TAX SENIOR
# 2         0.0                             DATABASE ADMINISTRATOR
# 3         0.0                                  SOFTWARE ENGINEER
# 4         0.0       MICROSOFT DYNAMICS CRM APPLICATION DEVELOPER
# 5         0.0                            SENIOR SYSTEM ARCHITECT
# 6         0.0                        SENIOR ORACLE ADF DEVELOPER
# 7         0.0                        SENIOR SYSTEMS ANALYST JC60
# 8         0.0              ASSOCIATE PRODUCT MANAGER(15-1199.09)
# 9         0.0                              SENIOR JAVA DEVELOPER
# 10        0.0                                 SOFTWARE DEVELOPER
# 11        0.0                       GLOBAL MMA ADVANCED ENGINEER
# 12        0.0                               TECHNICAL CONSULTANT
# 13        0.0                                           ENGINEER
# 14        0.0                                   BUSINESS ANALYST
# 15        0.0                                SOLUTIONS ARCHITECT
# 16        0.0  MEMBER TECHNICAL STAFF CONSULTANT-SYSTEMS ENGI...
# 17        0.0                    BUSINESS DEVELOPMENT SPECIALIST
# 18        0.0                                     MARKET ANALYST
# 19        1.0                     VC CONSTRUCTION FIELD ENGINEER
# 20        0.0                               RESEARCH ASSOCIATE I
# 21        0.0                                  FINANCIAL ANALYST
# 22        0.0                              SR. SOFTWARE ENGINEER
# 23        0.0      MEMBER OF TECHNICAL STAFF (SOFTWARE ENGINEER)
# 24        0.0                                    FINANCE MANAGER
# 25        1.0                                    SYSTEMS ANALYST
# 26        1.0      FUNCTIONAL EXCELLENCE SPECIALIST - PURCHASING
# 27        0.0        APPLICATION SOFTWARE DEVELOPMENT CONSULTANT
# 28        0.0                 REGULATORY REPORTING ACCOUNTANT II
# 29        0.0                     SOFTWARE ENGINEER (1615.33573)
# ...       ...                                                ...
# 633050    0.0                                   MANUAL TEST LEAD
# 633051    0.0                                 IT SUPPORT LEAD II
# 633052    0.0                          SENIOR SOFTWARE DEVELOPER
# 633053    0.0                                       PROJECT LEAD
# 633054    0.0                             SENIOR SYSTEMS ANALYST
# 633055    0.0          HEALTH INFORMATION EXCHANGE (HIE) ANALYST
# 633056    0.0                                          TEST LEAD
# 633057    0.0                                            MANAGER
# 633058    0.0         PHYSICIAN (INTERNAL MEDICINE/RHEUMATOLOGY)
# 633059    0.0                    SOFTWARE DEVELOPMENT ENGINEER I
# 633060    0.0                           DEVELOPER USER INTERFACE
# 633061    0.0                               SOFTWARE ENGINEER II
# 633062    0.0                        SENIOR SYSTEMS ANALYST JC60
# 633063    0.0                    SCHOLARSHIP PROGRAM COORDINATOR
# 633064    0.0                      SENIOR IT APPLICATION ANALYST
# 633065    0.0                                   GRAPHIC DESIGNER
# 633066    0.0                                 PROGRAMMER ANALYST
# 633067    0.0                               ETL/BIG DATA ANALYST
# 633068    0.0                                          DEVELOPER
# 633069    0.0                                   SYSTEMS ENGINEER
# 633070    0.0               HUMAN RESOURCES GENERALIST/RECRUITER
# 633071    0.0                                   BUSINESS ANALYST
# 633072    0.0           PRINCIPAL CONSULTANT - US - PRACTITIONER
# 633073    0.0                        COMPUTER SYSTEMS ENGINEER 1
# 633074    0.0                                  SOFTWARE ENGINEER
# 633075    0.0                        ASSOCIATE SOFTWARE ENGINEER
# 633076    0.0     MANAGER GLOBAL SUPPLY CHAIN BUSINESS ANALYTICS
# 633077    0.0                  BUSINESS RESEARCH AND DEVELOPMENT
# 633078    0.0                        PACKAGE SOLUTION CONSULTANT
# 633079    0.0                                  SOFTWARE ENGINEER
#
# [633080 rows x 25 columns]

# %%
df.loc[df.AGENT_REPRESENTING_EMPLOYER == 'N', 'AGENT_ATTORNEY_CITY_BIN'] = "None"

# %%
df.loc[df.AGENT_REPRESENTING_EMPLOYER == 'N', 'AGENT_ATTORNEY_STATE_BIN'] = "None"

# %%
df.head()
# Out:
#   EMPLOYER_NAME_BIN EMPLOYER_CITY_BIN H1B_DEPENDENT NAICS_CODE_BIN  \
# 0              Bin5              Bin7             N         Others
# 1              Bin2              Bin5             N           Bin1
# 2            Others              Bin5             N           Bin3
# 3              Bin5              Bin7             Y           Bin3
# 4            Others              Bin7             Y           Bin3
#
#   Visa_duration_bin AGENT_ATTORNEY_CITY_BIN PREVAILING_WAGE_BIN  \
# 0           2-3 yrs                    None                Bin4
# 1           2-3 yrs                    Bin3                Bin4
# 2           2-3 yrs                    None                Bin4
# 3           2-3 yrs                    Bin4                Bin4
# 4           2-3 yrs                    Bin5                Bin4
#
#   SOC_REVISED_CODE PW_UNIT_OF_PAY PW_SOURCE  ... AGENT_ATTORNEY_STATE_BIN  \
# 0               15           Year       OES  ...                     None
# 1               13           Year       OES  ...                   Others
# 2               15           Year       OES  ...                     None
# 3               15           Year       OES  ...                   Others
# 4               15           Year       OES  ...                     Bin4
#
#   AMENDED_PETITION_BIN AGENT_REPRESENTING_EMPLOYER FULL_TIME_POSITION  \
# 0                    0                           N                  Y
# 1                    0                           Y                  Y
# 2                    0                           N                  Y
# 3                    0                           Y                  Y
# 4                    1                           Y                  Y
#
#   WORKSITE_STATE_BIN NEW_EMPLOYMENT_BIN CHANGE_PREVIOUS_EMPLOYMENT_BIN  \
# 0               bin5                  0                              0
# 1               Bin1                  0                              0
# 2               Bin2                  0                              0
# 3             Others                 >1                              0
# 4             Others                  0                              0
#
#   WORKSITE_CITY_BIN Target                                     JOB_TITLE
# 0            Others    0.0                             SOFTWARE ENGINEER
# 1            Others    0.0                                    TAX SENIOR
# 2              Bin2    0.0                        DATABASE ADMINISTRATOR
# 3            Others    0.0                             SOFTWARE ENGINEER
# 4              Bin4    0.0  MICROSOFT DYNAMICS CRM APPLICATION DEVELOPER
#
# [5 rows x 25 columns]

# %%
df.loc[df.WORKSITE_STATE_BIN == 'bin4', 'WORKSITE_STATE_BIN'] = "Bin4"
df.loc[df.WORKSITE_STATE_BIN == 'bin5', 'WORKSITE_STATE_BIN'] = "Bin5"
df.loc[df.WORKSITE_STATE_BIN == 'bin6', 'WORKSITE_STATE_BIN'] = "Bin6"

# %%
df.head(10)
# Out:
#   EMPLOYER_NAME_BIN EMPLOYER_CITY_BIN H1B_DEPENDENT NAICS_CODE_BIN  \
# 0              Bin5              Bin7             N         Others
# 1              Bin2              Bin5             N           Bin1
# 2            Others              Bin5             N           Bin3
# 3              Bin5              Bin7             Y           Bin3
# 4            Others              Bin7             Y           Bin3
# 5            Others              Bin5             Y           Bin3
# 6            Others              Bin4             Y           Bin3
# 7              Bin5              Bin7             Y           Bin2
# 8            Others              Bin4           NaN           Bin3
# 9            Others              Bin5             Y           Bin3
#
#   Visa_duration_bin AGENT_ATTORNEY_CITY_BIN PREVAILING_WAGE_BIN  \
# 0           2-3 yrs                    None                Bin4
# 1           2-3 yrs                    Bin3                Bin4
# 2           2-3 yrs                    None                Bin4
# 3           2-3 yrs                    Bin4                Bin4
# 4           2-3 yrs                    Bin5                Bin4
# 5           2-3 yrs                    Bin1                Bin4
# 6              <1yr                    None                Bin4
# 7           2-3 yrs                    None                Bin4
# 8           1-2 yrs                    None                Bin4
# 9           2-3 yrs                    Bin4                Bin4
#
#   SOC_REVISED_CODE PW_UNIT_OF_PAY PW_SOURCE  ... AGENT_ATTORNEY_STATE_BIN  \
# 0               15           Year       OES  ...                     None
# 1               13           Year       OES  ...                   Others
# 2               15           Year       OES  ...                     None
# 3               15           Year       OES  ...                   Others
# 4               15           Year       OES  ...                     Bin4
# 5               15           Year     Other  ...                     Bin1
# 6               15           Year     Other  ...                     None
# 7               15           Year       OES  ...                     None
# 8               15           Year       OES  ...                     None
# 9               15           Year       OES  ...                     Bin4
#
#   AMENDED_PETITION_BIN AGENT_REPRESENTING_EMPLOYER FULL_TIME_POSITION  \
# 0                    0                           N                  Y
# 1                    0                           Y                  Y
# 2                    0                           N                  Y
# 3                    0                           Y                  Y
# 4                    1                           Y                  Y
# 5                    1                           Y                  Y
# 6                    0                           N                  Y
# 7                    0                           N                  Y
# 8                    0                           N                  Y
# 9                    0                           Y                  Y
#
#   WORKSITE_STATE_BIN NEW_EMPLOYMENT_BIN CHANGE_PREVIOUS_EMPLOYMENT_BIN  \
# 0               Bin5                  0                              0
# 1               Bin1                  0                              0
# 2               Bin2                  0                              0
# 3             Others                 >1                              0
# 4             Others                  0                              0
# 5               Bin7                  0                              0
# 6               Bin7                  0                              0
# 7             Others                  0                              0
# 8               Bin4                  0                              0
# 9               Bin7                  0                              0
#
#   WORKSITE_CITY_BIN Target                                     JOB_TITLE
# 0            Others    0.0                             SOFTWARE ENGINEER
# 1            Others    0.0                                    TAX SENIOR
# 2              Bin2    0.0                        DATABASE ADMINISTRATOR
# 3            Others    0.0                             SOFTWARE ENGINEER
# 4              Bin4    0.0  MICROSOFT DYNAMICS CRM APPLICATION DEVELOPER
# 5            Others    0.0                       SENIOR SYSTEM ARCHITECT
# 6              Bin3    0.0                   SENIOR ORACLE ADF DEVELOPER
# 7            Others    0.0                   SENIOR SYSTEMS ANALYST JC60
# 8              Bin3    0.0         ASSOCIATE PRODUCT MANAGER(15-1199.09)
# 9              Bin3    0.0                         SENIOR JAVA DEVELOPER
#
# [10 rows x 25 columns]

# %%
df.loc[df.EMPLOYER_STATE_BIN == 'bin4', 'EMPLOYER_STATE_BIN'] = "Bin4"
df.loc[df.EMPLOYER_STATE_BIN == 'bin5', 'EMPLOYER_STATE_BIN'] = "Bin5"
df.loc[df.EMPLOYER_STATE_BIN == 'bin6', 'EMPLOYER_STATE_BIN'] = "Bin6"

# %%
def num_missing(x):
  return sum(x.isnull())

#Applying per column:
print("Missing values per column:")
print(df.apply(num_missing, axis=0)) #axis=0 defines that function is to be applied on each column
# Out:
# Missing values per column:
# EMPLOYER_NAME_BIN                     0
# EMPLOYER_CITY_BIN                     0
# H1B_DEPENDENT                     13720
# NAICS_CODE_BIN                        0
# Visa_duration_bin                     0
# AGENT_ATTORNEY_CITY_BIN               0
# PREVAILING_WAGE_BIN                   0
# SOC_REVISED_CODE                  20578
# PW_UNIT_OF_PAY                       51
# PW_SOURCE                            49
# WAGE_UNIT_OF_PAY                     10
# EMPLOYER_STATE_BIN                    0
# WORKSITE_STATE                       10
# PW_WAGE_LEVEL                     37318
# WORKSITE_COUNTY_BIN                   0
# AGENT_ATTORNEY_STATE_BIN              0
# AMENDED_PETITION_BIN                  0
# AGENT_REPRESENTING_EMPLOYER          16
# FULL_TIME_POSITION                    4
# WORKSITE_STATE_BIN                    0
# NEW_EMPLOYMENT_BIN                    0
# CHANGE_PREVIOUS_EMPLOYMENT_BIN        0
# WORKSITE_CITY_BIN                     0
# Target                                0
# JOB_TITLE                             2
# dtype: int64

# %%
df.head()
# Out:
#   EMPLOYER_NAME_BIN EMPLOYER_CITY_BIN H1B_DEPENDENT NAICS_CODE_BIN  \
# 0              Bin5              Bin7             N         Others
# 1              Bin2              Bin5             N           Bin1
# 2            Others              Bin5             N           Bin3
# 3              Bin5              Bin7             Y           Bin3
# 4            Others              Bin7             Y           Bin3
#
#   Visa_duration_bin AGENT_ATTORNEY_CITY_BIN PREVAILING_WAGE_BIN  \
# 0           2-3 yrs                    None                Bin4
# 1           2-3 yrs                    Bin3                Bin4
# 2           2-3 yrs                    None                Bin4
# 3           2-3 yrs                    Bin4                Bin4
# 4           2-3 yrs                    Bin5                Bin4
#
#   SOC_REVISED_CODE PW_UNIT_OF_PAY PW_SOURCE  ... AGENT_ATTORNEY_STATE_BIN  \
# 0               15           Year       OES  ...                     None
# 1               13           Year       OES  ...                   Others
# 2               15           Year       OES  ...                     None
# 3               15           Year       OES  ...                   Others
# 4               15           Year       OES  ...                     Bin4
#
#   AMENDED_PETITION_BIN AGENT_REPRESENTING_EMPLOYER FULL_TIME_POSITION  \
# 0                    0                           N                  Y
# 1                    0                           Y                  Y
# 2                    0                           N                  Y
# 3                    0                           Y                  Y
# 4                    1                           Y                  Y
#
#   WORKSITE_STATE_BIN NEW_EMPLOYMENT_BIN CHANGE_PREVIOUS_EMPLOYMENT_BIN  \
# 0               Bin5                  0                              0
# 1               Bin1                  0                              0
# 2               Bin2                  0                              0
# 3             Others                 >1                              0
# 4             Others                  0                              0
#
#   WORKSITE_CITY_BIN Target                                     JOB_TITLE
# 0            Others    0.0                             SOFTWARE ENGINEER
# 1            Others    0.0                                    TAX SENIOR
# 2              Bin2    0.0                        DATABASE ADMINISTRATOR
# 3            Others    0.0                             SOFTWARE ENGINEER
# 4              Bin4    0.0  MICROSOFT DYNAMICS CRM APPLICATION DEVELOPER
#
# [5 rows x 25 columns]

# %%
df['H1B_DEPENDENT'].value_counts()
# Out:
# N    398244
# Y    221116
# Name: H1B_DEPENDENT, dtype: int64

# %%
#fill missing values with mode 
df['H1B_DEPENDENT']=df['H1B_DEPENDENT'].fillna('N')
df.head(10)
# Out:
#   EMPLOYER_NAME_BIN EMPLOYER_CITY_BIN H1B_DEPENDENT NAICS_CODE_BIN  \
# 0              Bin5              Bin7             N         Others
# 1              Bin2              Bin5             N           Bin1
# 2            Others              Bin5             N           Bin3
# 3              Bin5              Bin7             Y           Bin3
# 4            Others              Bin7             Y           Bin3
# 5            Others              Bin5             Y           Bin3
# 6            Others              Bin4             Y           Bin3
# 7              Bin5              Bin7             Y           Bin2
# 8            Others              Bin4             N           Bin3
# 9            Others              Bin5             Y           Bin3
#
#   Visa_duration_bin AGENT_ATTORNEY_CITY_BIN PREVAILING_WAGE_BIN  \
# 0           2-3 yrs                    None                Bin4
# 1           2-3 yrs                    Bin3                Bin4
# 2           2-3 yrs                    None                Bin4
# 3           2-3 yrs                    Bin4                Bin4
# 4           2-3 yrs                    Bin5                Bin4
# 5           2-3 yrs                    Bin1                Bin4
# 6              <1yr                    None                Bin4
# 7           2-3 yrs                    None                Bin4
# 8           1-2 yrs                    None                Bin4
# 9           2-3 yrs                    Bin4                Bin4
#
#   SOC_REVISED_CODE PW_UNIT_OF_PAY PW_SOURCE  ... AGENT_ATTORNEY_STATE_BIN  \
# 0               15           Year       OES  ...                     None
# 1               13           Year       OES  ...                   Others
# 2               15           Year       OES  ...                     None
# 3               15           Year       OES  ...                   Others
# 4               15           Year       OES  ...                     Bin4
# 5               15           Year     Other  ...                     Bin1
# 6               15           Year     Other  ...                     None
# 7               15           Year       OES  ...                     None
# 8               15           Year       OES  ...                     None
# 9               15           Year       OES  ...                     Bin4
#
#   AMENDED_PETITION_BIN AGENT_REPRESENTING_EMPLOYER FULL_TIME_POSITION  \
# 0                    0                           N                  Y
# 1                    0                           Y                  Y
# 2                    0                           N                  Y
# 3                    0                           Y                  Y
# 4                    1                           Y                  Y
# 5                    1                           Y                  Y
# 6                    0                           N                  Y
# 7                    0                           N                  Y
# 8                    0                           N                  Y
# 9                    0                           Y                  Y
#
#   WORKSITE_STATE_BIN NEW_EMPLOYMENT_BIN CHANGE_PREVIOUS_EMPLOYMENT_BIN  \
# 0               Bin5                  0                              0
# 1               Bin1                  0                              0
# 2               Bin2                  0                              0
# 3             Others                 >1                              0
# 4             Others                  0                              0
# 5               Bin7                  0                              0
# 6               Bin7                  0                              0
# 7             Others                  0                              0
# 8               Bin4                  0                              0
# 9               Bin7                  0                              0
#
#   WORKSITE_CITY_BIN Target                                     JOB_TITLE
# 0            Others    0.0                             SOFTWARE ENGINEER
# 1            Others    0.0                                    TAX SENIOR
# 2              Bin2    0.0                        DATABASE ADMINISTRATOR
# 3            Others    0.0                             SOFTWARE ENGINEER
# 4              Bin4    0.0  MICROSOFT DYNAMICS CRM APPLICATION DEVELOPER
# 5            Others    0.0                       SENIOR SYSTEM ARCHITECT
# 6              Bin3    0.0                   SENIOR ORACLE ADF DEVELOPER
# 7            Others    0.0                   SENIOR SYSTEMS ANALYST JC60
# 8              Bin3    0.0         ASSOCIATE PRODUCT MANAGER(15-1199.09)
# 9              Bin3    0.0                         SENIOR JAVA DEVELOPER
#
# [10 rows x 25 columns]

# %%
df['PW_WAGE_LEVEL'].value_counts()
# Out:
# Level II     319693
# Level I      107667
# Level III    107617
# Level IV      60785
# Name: PW_WAGE_LEVEL, dtype: int64

# %%
dfwage = dfwage[['PREVAILING_WAGE', 'PW_WAGE_LEVEL']].copy()
dfwage.head()
# Out:
#    PREVAILING_WAGE PW_WAGE_LEVEL
# 0         112549.0      Level II
# 1          79976.0      Level II
# 2          77792.0      Level II
# 3          84406.0      Level II
# 4          87714.0     Level III

# %%
dfwagemissing=dfwage[dfwage.isnull().any(axis=1)]
dfwagemissing
# Out:
#         PREVAILING_WAGE PW_WAGE_LEVEL
# 16              81780.0           NaN
# 17              50700.0           NaN
# 20              67879.0           NaN
# 21              58597.0           NaN
# 22             126539.0           NaN
# 23             110287.0           NaN
# 24             123363.0           NaN
# 27              75717.0           NaN
# 28              53000.0           NaN
# 29             125000.0           NaN
# 30             116802.0           NaN
# 32             116802.0           NaN
# 33              66563.0           NaN
# 34             112235.0           NaN
# 37             140376.0           NaN
# 38              79280.0           NaN
# 39             106983.0           NaN
# 45              87300.0           NaN
# 59              99939.0           NaN
# 60             103200.0           NaN
# 61             112536.0           NaN
# 62             104300.0           NaN
# 65             111920.0           NaN
# 83             149782.0           NaN
# 84             136423.0           NaN
# 85             110928.0           NaN
# 87              87993.0           NaN
# 89             160196.0           NaN
# 90              86300.0           NaN
# 91              67100.0           NaN
# ...                 ...           ...
# 628450          59705.0           NaN
# 628633          48432.0           NaN
# 628904          39229.0           NaN
# 628952         197780.0           NaN
# 629057          48216.0           NaN
# 629156          71004.0           NaN
# 629246          62247.0           NaN
# 629316         104400.0           NaN
# 629385          45000.0           NaN
# 629476          56250.0           NaN
# 629662          35360.0           NaN
# 629753          39229.0           NaN
# 630076          41600.0           NaN
# 630138          57084.0           NaN
# 630209          76960.0           NaN
# 630615          75924.0           NaN
# 630911          68124.0           NaN
# 630923          46725.0           NaN
# 631003          49920.0           NaN
# 631030          76960.0           NaN
# 631116          60320.0           NaN
# 631161          70192.0           NaN
# 631181          69822.0           NaN
# 631345          38334.0           NaN
# 631667          50242.0           NaN
# 632211          52000.0           NaN
# 632430          80813.0           NaN
# 632471         129856.0           NaN
# 632745          56618.0           NaN
# 632747          35702.0           NaN
#
# [37320 rows x 2 columns]

# %%
dfwagemissing['PW_WAGE_LEVEL']=dfwagemissing['PW_WAGE_LEVEL'].fillna('N')
dfwagemissing.head()
# Out:
# C:\Users\varun\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#     PREVAILING_WAGE PW_WAGE_LEVEL
# 16          81780.0             N
# 17          50700.0             N
# 20          67879.0             N
# 21          58597.0             N
# 22         126539.0             N

# %%
dfwage=dfwage.dropna()
dfwage.shape
# Out:
# (595760, 2)

# %%
dfwage.isna().sum()
# Out:
# PREVAILING_WAGE    0
# PW_WAGE_LEVEL      0
# dtype: int64

# %%
dfwagemissing.isna().sum()
# Out:
# PREVAILING_WAGE    3
# PW_WAGE_LEVEL      0
# dtype: int64

# %%
from sklearn.naive_bayes import GaussianNB
Xtrain=dfwage[['PREVAILING_WAGE']]
Ytrain=dfwage[['PW_WAGE_LEVEL']]
Xtest=dfwagemissing[['PREVAILING_WAGE']]
Xtest=Xtest.fillna(Xtest.mean())
clf = GaussianNB().fit(Xtrain, Ytrain)
Ytest= clf.predict(Xtest) 
print ("Predicted Value:", Ytest)
# Out:
# C:\Users\varun\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Predicted Value: ['Level II' 'Level I' 'Level II' ... 'Level III' 'Level II' 'Level I']

# %%
set(Ytest)
# Out:
# {'Level I', 'Level II', 'Level III', 'Level IV'}

# %%
len(Ytest)
# Out:
# 37320

# %%
dfwagemissing.shape
# Out:
# (37320, 2)

# %%
Xtest['FILLED_VALUE'] = Ytest.tolist()
Xtest
# Out:
#         PREVAILING_WAGE FILLED_VALUE
# 16              81780.0     Level II
# 17              50700.0      Level I
# 20              67879.0     Level II
# 21              58597.0     Level II
# 22             126539.0    Level III
# 23             110287.0     Level II
# 24             123363.0    Level III
# 27              75717.0     Level II
# 28              53000.0     Level II
# 29             125000.0    Level III
# 30             116802.0    Level III
# 32             116802.0    Level III
# 33              66563.0     Level II
# 34             112235.0     Level II
# 37             140376.0     Level IV
# 38              79280.0     Level II
# 39             106983.0     Level II
# 45              87300.0     Level II
# 59              99939.0     Level II
# 60             103200.0     Level II
# 61             112536.0     Level II
# 62             104300.0     Level II
# 65             111920.0     Level II
# 83             149782.0     Level IV
# 84             136423.0    Level III
# 85             110928.0     Level II
# 87              87993.0     Level II
# 89             160196.0     Level IV
# 90              86300.0     Level II
# 91              67100.0     Level II
# ...                 ...          ...
# 628450          59705.0     Level II
# 628633          48432.0      Level I
# 628904          39229.0      Level I
# 628952         197780.0     Level IV
# 629057          48216.0      Level I
# 629156          71004.0     Level II
# 629246          62247.0     Level II
# 629316         104400.0     Level II
# 629385          45000.0      Level I
# 629476          56250.0     Level II
# 629662          35360.0      Level I
# 629753          39229.0      Level I
# 630076          41600.0      Level I
# 630138          57084.0     Level II
# 630209          76960.0     Level II
# 630615          75924.0     Level II
# 630911          68124.0     Level II
# 630923          46725.0      Level I
# 631003          49920.0      Level I
# 631030          76960.0     Level II
# 631116          60320.0     Level II
# 631161          70192.0     Level II
# 631181          69822.0     Level II
# 631345          38334.0      Level I
# 631667          50242.0      Level I
# 632211          52000.0      Level I
# 632430          80813.0     Level II
# 632471         129856.0    Level III
# 632745          56618.0     Level II
# 632747          35702.0      Level I
#
# [37320 rows x 2 columns]

# %%
df3=df.loc[df['PW_WAGE_LEVEL'].isnull()]

# %%
df3.index
# Out:
# Int64Index([    16,     17,     20,     21,     22,     23,     24,     27,
#                 28,     29,
#             ...
#             631116, 631161, 631181, 631345, 631667, 632211, 632430, 632471,
#             632745, 632747],
#            dtype='int64', length=37318)

# %%
df3.shape
# Out:
# (37318, 25)

# %%
df4=df.drop(df3.index)

# %%
df4.shape
# Out:
# (595762, 25)

# %%
df3=df3.drop(['PW_WAGE_LEVEL'], axis=1)
df3.shape
# Out:
# (37318, 24)

# %%
df3['PW_WAGE_LEVEL']=Xtest['FILLED_VALUE']

# %%
df3.head()
# Out:
#    EMPLOYER_NAME_BIN EMPLOYER_CITY_BIN H1B_DEPENDENT NAICS_CODE_BIN  \
# 16            Others              Bin5             N         Others
# 17            Others              Bin1             N         Others
# 20            Others            Others             N           Bin1
# 21            Others            Others             N         Others
# 22            Others              Bin2             N           Bin1
#
#    Visa_duration_bin AGENT_ATTORNEY_CITY_BIN PREVAILING_WAGE_BIN  \
# 16           2-3 yrs                    Bin4                Bin4
# 17           2-3 yrs                  Others                Bin3
# 20           2-3 yrs                    Bin4                Bin4
# 21           2-3 yrs                    Bin1                Bin4
# 22           2-3 yrs                    Bin1                Bin5
#
#    SOC_REVISED_CODE PW_UNIT_OF_PAY PW_SOURCE  ... AMENDED_PETITION_BIN  \
# 16               15           Year     Other  ...                    0
# 17               13           Year     Other  ...                    0
# 20               19           Year     Other  ...                    0
# 21               13           Year     Other  ...                    0
# 22               15           Year     Other  ...                    0
#
#    AGENT_REPRESENTING_EMPLOYER FULL_TIME_POSITION WORKSITE_STATE_BIN  \
# 16                           Y                  Y               Bin2
# 17                           Y                  Y               Bin6
# 20                           Y                  Y               Bin1
# 21                           Y                  Y               Bin4
# 22                           Y                  Y               Bin1
#
#    NEW_EMPLOYMENT_BIN CHANGE_PREVIOUS_EMPLOYMENT_BIN WORKSITE_CITY_BIN Target  \
# 16                  1                              0              Bin2    0.0
# 17                  0                              0              Bin2    0.0
# 20                  1                              0            Others    0.0
# 21                  1                              0              Bin3    0.0
# 22                  1                              0            Others    0.0
#
#                                             JOB_TITLE PW_WAGE_LEVEL
# 16  MEMBER TECHNICAL STAFF CONSULTANT-SYSTEMS ENGI...      Level II
# 17                    BUSINESS DEVELOPMENT SPECIALIST       Level I
# 20                               RESEARCH ASSOCIATE I      Level II
# 21                                  FINANCIAL ANALYST      Level II
# 22                              SR. SOFTWARE ENGINEER     Level III
#
# [5 rows x 25 columns]

# %%
df4.columns
# Out:
# Index(['EMPLOYER_NAME_BIN', 'EMPLOYER_CITY_BIN', 'H1B_DEPENDENT',
#        'NAICS_CODE_BIN', 'Visa_duration_bin', 'AGENT_ATTORNEY_CITY_BIN',
#        'PREVAILING_WAGE_BIN', 'SOC_REVISED_CODE', 'PW_UNIT_OF_PAY',
#        'PW_SOURCE', 'WAGE_UNIT_OF_PAY', 'EMPLOYER_STATE_BIN', 'WORKSITE_STATE',
#        'PW_WAGE_LEVEL', 'WORKSITE_COUNTY_BIN', 'AGENT_ATTORNEY_STATE_BIN',
#        'AMENDED_PETITION_BIN', 'AGENT_REPRESENTING_EMPLOYER',
#        'FULL_TIME_POSITION', 'WORKSITE_STATE_BIN', 'NEW_EMPLOYMENT_BIN',
#        'CHANGE_PREVIOUS_EMPLOYMENT_BIN', 'WORKSITE_CITY_BIN', 'Target',
#        'JOB_TITLE'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['EMPLOYER_NAME_BIN', 'EMPLOYER_CITY_BIN', 'H1B_DEPENDENT',
#        'NAICS_CODE_BIN', 'Visa_duration_bin', 'AGENT_ATTORNEY_CITY_BIN',
#        'PREVAILING_WAGE_BIN', 'SOC_REVISED_CODE', 'PW_UNIT_OF_PAY',
#        'PW_SOURCE', 'WAGE_UNIT_OF_PAY', 'EMPLOYER_STATE_BIN', 'WORKSITE_STATE',
#        'WORKSITE_COUNTY_BIN', 'AGENT_ATTORNEY_STATE_BIN',
#        'AMENDED_PETITION_BIN', 'AGENT_REPRESENTING_EMPLOYER',
#        'FULL_TIME_POSITION', 'WORKSITE_STATE_BIN', 'NEW_EMPLOYMENT_BIN',
#        'CHANGE_PREVIOUS_EMPLOYMENT_BIN', 'WORKSITE_CITY_BIN', 'Target',
#        'JOB_TITLE', 'PW_WAGE_LEVEL'],
#       dtype='object')

# %%
df3=df3[['EMPLOYER_NAME_BIN', 'EMPLOYER_CITY_BIN', 'H1B_DEPENDENT',
       'NAICS_CODE_BIN', 'Visa_duration_bin', 'AGENT_ATTORNEY_CITY_BIN',
       'PREVAILING_WAGE_BIN', 'SOC_REVISED_CODE', 'PW_UNIT_OF_PAY',
       'PW_SOURCE', 'WAGE_UNIT_OF_PAY', 'EMPLOYER_STATE_BIN', 'WORKSITE_STATE',
       'PW_WAGE_LEVEL', 'WORKSITE_COUNTY_BIN', 'AGENT_ATTORNEY_STATE_BIN',
       'AMENDED_PETITION_BIN', 'AGENT_REPRESENTING_EMPLOYER',
       'FULL_TIME_POSITION', 'WORKSITE_STATE_BIN', 'NEW_EMPLOYMENT_BIN',
       'CHANGE_PREVIOUS_EMPLOYMENT_BIN', 'WORKSITE_CITY_BIN','Target','JOB_TITLE']]

# %%
df3.head(21)
# Out:
#    EMPLOYER_NAME_BIN EMPLOYER_CITY_BIN H1B_DEPENDENT NAICS_CODE_BIN  \
# 16            Others              Bin5             N         Others
# 17            Others              Bin1             N         Others
# 20            Others            Others             N           Bin1
# 21            Others            Others             N         Others
# 22            Others              Bin2             N           Bin1
# 23            Others              Bin6             N         Others
# 24            Others              Bin3             N           Bin1
# 27              Bin1              Bin1             N           Bin3
# 28            Others              Bin1             N           Bin2
# 29              Bin1              Bin2             N           Bin2
# 30            Others              Bin1             N           Bin3
# 32            Others              Bin1             N           Bin3
# 33            Others              Bin1             N           Bin1
# 34            Others              Bin4             N         Others
# 37              Bin2              Bin4             Y           Bin2
# 38              Bin2              Bin4             N           Bin2
# 39              Bin1              Bin2             N           Bin2
# 45            Others              Bin4             N         Others
# 59            Others              Bin6             N           Bin2
# 60            Others              Bin1             N         Others
# 61              Bin2              Bin4             Y           Bin2
#
#    Visa_duration_bin AGENT_ATTORNEY_CITY_BIN PREVAILING_WAGE_BIN  \
# 16           2-3 yrs                    Bin4                Bin4
# 17           2-3 yrs                  Others                Bin3
# 20           2-3 yrs                    Bin4                Bin4
# 21           2-3 yrs                    Bin1                Bin4
# 22           2-3 yrs                    Bin1                Bin5
# 23           2-3 yrs                    Bin4                Bin4
# 24           2-3 yrs                    Bin2                Bin4
# 27           2-3 yrs                    Bin1                Bin4
# 28           2-3 yrs                    Bin2                Bin3
# 29           2-3 yrs                    Bin1                Bin4
# 30           2-3 yrs                    Bin1                Bin4
# 32           2-3 yrs                    Bin1                Bin4
# 33           1-2 yrs                    None                Bin4
# 34           2-3 yrs                    Bin4                Bin4
# 37           2-3 yrs                    Bin4                Bin5
# 38           2-3 yrs                    Bin2                Bin4
# 39           2-3 yrs                    Bin1                Bin4
# 45           2-3 yrs                    None                Bin4
# 59           2-3 yrs                    Bin4                Bin4
# 60           2-3 yrs                    Bin4                Bin4
# 61           2-3 yrs                    Bin4                Bin4
#
#    SOC_REVISED_CODE PW_UNIT_OF_PAY PW_SOURCE  ... AGENT_ATTORNEY_STATE_BIN  \
# 16               15           Year     Other  ...                     Bin1
# 17               13           Year     Other  ...                     Bin5
# 20               19           Year     Other  ...                     Bin3
# 21               13           Year     Other  ...                     Bin4
# 22               15           Year     Other  ...                     Bin1
# 23               15           Year     Other  ...                     Bin3
# 24               19           Year     Other  ...                     Bin3
# 27               15           Year     Other  ...                     Bin1
# 28               13           Year     Other  ...                     Bin2
# 29               15           Year     Other  ...                     Bin1
# 30               15           Year     Other  ...                     Bin1
# 32               15           Year     Other  ...                     Bin1
# 33               29           Year     Other  ...                     None
# 34               17           Year     Other  ...                     Bin3
# 37               15           Year     Other  ...                     Bin3
# 38               15           Year     Other  ...                     Bin2
# 39               15           Year     Other  ...                     Bin1
# 45               15           Year     Other  ...                     None
# 59               15           Year     Other  ...                     Bin3
# 60               25           Year     Other  ...                     Bin3
# 61               15           Year     Other  ...                     Bin3
#
#    AMENDED_PETITION_BIN AGENT_REPRESENTING_EMPLOYER FULL_TIME_POSITION  \
# 16                    0                           Y                  Y
# 17                    0                           Y                  Y
# 20                    0                           Y                  Y
# 21                    0                           Y                  Y
# 22                    0                           Y                  Y
# 23                    0                           Y                  Y
# 24                   >1                           Y                  Y
# 27                    0                           Y                  Y
# 28                    0                           Y                  Y
# 29                    0                           Y                  Y
# 30                    0                           Y                  Y
# 32                    0                           Y                  Y
# 33                    0                           N                  Y
# 34                    0                           Y                  Y
# 37                    0                           Y                  Y
# 38                    0                           Y                  Y
# 39                    0                           Y                  Y
# 45                    0                           N                  Y
# 59                    0                           Y                  Y
# 60                    0                           Y                  Y
# 61                    0                           Y                  Y
#
#    WORKSITE_STATE_BIN NEW_EMPLOYMENT_BIN CHANGE_PREVIOUS_EMPLOYMENT_BIN  \
# 16               Bin2                  1                              0
# 17               Bin6                  0                              0
# 20               Bin1                  1                              0
# 21               Bin4                  1                              0
# 22               Bin1                  1                              0
# 23               Bin1                  1                              0
# 24               Bin1                 >1                             >1
# 27             Others                  1                              0
# 28               Bin4                  1                              0
# 29               Bin1                  1                              0
# 30               Bin2                  1                              0
# 32               Bin2                  1                              0
# 33             Others                  0                              0
# 34               Bin1                 >1                              0
# 37               Bin1                  0                              0
# 38             Others                  1                              0
# 39               Bin1                  1                              0
# 45               Bin1                 >1                              0
# 59               Bin1                  0                              0
# 60               Bin1                  0                              0
# 61               Bin1                  0                              0
#
#    WORKSITE_CITY_BIN Target                                          JOB_TITLE
# 16              Bin2    0.0  MEMBER TECHNICAL STAFF CONSULTANT-SYSTEMS ENGI...
# 17              Bin2    0.0                    BUSINESS DEVELOPMENT SPECIALIST
# 20            Others    0.0                               RESEARCH ASSOCIATE I
# 21              Bin3    0.0                                  FINANCIAL ANALYST
# 22            Others    0.0                              SR. SOFTWARE ENGINEER
# 23            Others    0.0      MEMBER OF TECHNICAL STAFF (SOFTWARE ENGINEER)
# 24            Others    0.0                                    FINANCE MANAGER
# 27              Bin2    0.0        APPLICATION SOFTWARE DEVELOPMENT CONSULTANT
# 28              Bin3    0.0                 REGULATORY REPORTING ACCOUNTANT II
# 29            Others    0.0                     SOFTWARE ENGINEER (1615.33573)
# 30              Bin2    0.0                    DATABASE ADMINISTRATION ADVISOR
# 32              Bin2    0.0                       SOFTWARE DEVELOPMENT ADVISOR
# 33              Bin3    1.0                          INFECTIOUS DISEASE FELLOW
# 34            Others    0.0                                   PROCESS ENGINEER
# 37              Bin3    0.0                                  SOFTWARE ENGINEER
# 38              Bin2    0.0             VICE PRESIDENT; CONSULTANT - APPS PROG
# 39              Bin2    0.0                     SOFTWARE ENGINEER (1615.24086)
# 45            Others    0.0                                  SOFTWARE ENGINEER
# 59            Others    0.0          TECH YAHOO, SOFTWARE DEV ENGINEER, INTERM
# 60              Bin3    0.0                       SENIOR, SOFTWARE ENGINEERING
# 61              Bin3    0.0                                   PRODUCT DESIGNER
#
# [21 rows x 25 columns]

# %%
df4.head()
# Out:
#   EMPLOYER_NAME_BIN EMPLOYER_CITY_BIN H1B_DEPENDENT NAICS_CODE_BIN  \
# 0              Bin5              Bin7             N         Others
# 1              Bin2              Bin5             N           Bin1
# 2            Others              Bin5             N           Bin3
# 3              Bin5              Bin7             Y           Bin3
# 4            Others              Bin7             Y           Bin3
#
#   Visa_duration_bin AGENT_ATTORNEY_CITY_BIN PREVAILING_WAGE_BIN  \
# 0           2-3 yrs                    None                Bin4
# 1           2-3 yrs                    Bin3                Bin4
# 2           2-3 yrs                    None                Bin4
# 3           2-3 yrs                    Bin4                Bin4
# 4           2-3 yrs                    Bin5                Bin4
#
#   SOC_REVISED_CODE PW_UNIT_OF_PAY PW_SOURCE  ... AGENT_ATTORNEY_STATE_BIN  \
# 0               15           Year       OES  ...                     None
# 1               13           Year       OES  ...                   Others
# 2               15           Year       OES  ...                     None
# 3               15           Year       OES  ...                   Others
# 4               15           Year       OES  ...                     Bin4
#
#   AMENDED_PETITION_BIN AGENT_REPRESENTING_EMPLOYER FULL_TIME_POSITION  \
# 0                    0                           N                  Y
# 1                    0                           Y                  Y
# 2                    0                           N                  Y
# 3                    0                           Y                  Y
# 4                    1                           Y                  Y
#
#   WORKSITE_STATE_BIN NEW_EMPLOYMENT_BIN CHANGE_PREVIOUS_EMPLOYMENT_BIN  \
# 0               Bin5                  0                              0
# 1               Bin1                  0                              0
# 2               Bin2                  0                              0
# 3             Others                 >1                              0
# 4             Others                  0                              0
#
#   WORKSITE_CITY_BIN Target                                     JOB_TITLE
# 0            Others    0.0                             SOFTWARE ENGINEER
# 1            Others    0.0                                    TAX SENIOR
# 2              Bin2    0.0                        DATABASE ADMINISTRATOR
# 3            Others    0.0                             SOFTWARE ENGINEER
# 4              Bin4    0.0  MICROSOFT DYNAMICS CRM APPLICATION DEVELOPER
#
# [5 rows x 25 columns]

# %%
df5=pd.concat([df3, df4])
df5.shape
# Out:
# (633080, 25)

# %%
df5['SOC_REVISED_CODE'].value_counts()
# Out:
# 15.0    361435
# 15       57032
# 13.0     44046
# 17.0     39801
# 19.0     25338
# 29.0     17881
# 25.0     12899
# 20.0     12634
# 27.0      7348
# 13        6876
# 17        6038
# 19        3902
# 41.0      2733
# 23.0      2125
# 11.0      2095
# 29        2069
# 25        1957
# 20        1721
# 27        1143
# 21.0      1072
# 41         404
# 43.0       403
# 11         243
# 23         219
# 53.0       207
# 21         149
# 39.0       117
# 35.0        88
# 51.0        79
# 49.0        71
#          ...
# 31           7
# 35           6
# SO           6
# 40           5
# 73           5
# 49           5
# 36           4
# 33           4
# 71           3
# 12           3
# 47           3
# 38           3
# EL           2
# 73           2
# 18           2
# 46           1
# AI           1
# AC           1
# 28           1
# 50           1
# 71           1
# 22           1
# 24           1
# 79           1
# 26           1
# CO           1
# 40           1
# 75           1
# 74           1
# 10           1
# Name: SOC_REVISED_CODE, Length: 71, dtype: int64

# %%
#fill missing values with mode 
df5['SOC_REVISED_CODE']=df5['SOC_REVISED_CODE'].fillna('15')

# %%
df5=df5.drop(columns=['JOB_TITLE'])

# %%
df5.shape
# Out:
# (633080, 24)

# %%
df5['SOC_REVISED_CODE'].value_counts()
# Out:
# 15.0    361435
# 15       77610
# 13.0     44046
# 17.0     39801
# 19.0     25338
# 29.0     17881
# 25.0     12899
# 20.0     12634
# 27.0      7348
# 13        6876
# 17        6038
# 19        3902
# 41.0      2733
# 23.0      2125
# 11.0      2095
# 29        2069
# 25        1957
# 20        1721
# 27        1143
# 21.0      1072
# 41         404
# 43.0       403
# 11         243
# 23         219
# 53.0       207
# 21         149
# 39.0       117
# 35.0        88
# 51.0        79
# 49.0        71
#          ...
# 31           7
# 35           6
# SO           6
# 40           5
# 73           5
# 49           5
# 36           4
# 33           4
# 71           3
# 12           3
# 47           3
# 38           3
# EL           2
# 73           2
# 18           2
# 46           1
# AI           1
# AC           1
# 28           1
# 50           1
# 71           1
# 22           1
# 24           1
# 79           1
# 26           1
# CO           1
# 40           1
# 75           1
# 74           1
# 10           1
# Name: SOC_REVISED_CODE, Length: 71, dtype: int64

# %%
df5['SOC_REVISED_CODE'].unique()
# Out:
# array([15.0, 13.0, 19.0, 29.0, 17.0, 25.0, 20.0, 51.0, 27.0, 23.0, 11.0,
#        41.0, 43.0, 21.0, 45.0, 47.0, 35.0, 49.0, 53.0, '15', 39.0, 31.0,
#        33.0, 37.0, '29', '19', '13', '17', '20', '27', '11', '25', '41',
#        '23', '53', '21', 16, '45', '43', '39', '35', '51', '33', 'SO',
#        '47', 40, 73, '31', '50', '73', '75', 38, 18, 12, 46, 'AC', '49',
#        'AI', 24, 71, '28', 36, 26, '79', 'EL', '40', 74, 10, 22, '71',
#        'CO'], dtype=object)

# %%
df5.loc[df5.SOC_REVISED_CODE == 15, 'SOC_REVISED_CODE'] = '15'
df5.loc[df5.SOC_REVISED_CODE == 13, 'SOC_REVISED_CODE'] = '13'
df5.loc[df5.SOC_REVISED_CODE == 19, 'SOC_REVISED_CODE'] = '19'

# %%
df5.loc[df5.SOC_REVISED_CODE == 29, 'SOC_REVISED_CODE'] = '29'
df5.loc[df5.SOC_REVISED_CODE == 17, 'SOC_REVISED_CODE'] = '17'
df5.loc[df5.SOC_REVISED_CODE == 25, 'SOC_REVISED_CODE'] = '25'
df5.loc[df5.SOC_REVISED_CODE == 20, 'SOC_REVISED_CODE'] = '20'
df5.loc[df5.SOC_REVISED_CODE == 51, 'SOC_REVISED_CODE'] = '51'
df5.loc[df5.SOC_REVISED_CODE == 27, 'SOC_REVISED_CODE'] = '27'
df5.loc[df5.SOC_REVISED_CODE == 23, 'SOC_REVISED_CODE'] = '23'
df5.loc[df5.SOC_REVISED_CODE == 11, 'SOC_REVISED_CODE'] = '11'
df5.loc[df5.SOC_REVISED_CODE == 41, 'SOC_REVISED_CODE'] = '41'
df5.loc[df5.SOC_REVISED_CODE == 43, 'SOC_REVISED_CODE'] = '43'
df5.loc[df5.SOC_REVISED_CODE == 21, 'SOC_REVISED_CODE'] = '21'
df5.loc[df5.SOC_REVISED_CODE == 45, 'SOC_REVISED_CODE'] = '45'
df5.loc[df5.SOC_REVISED_CODE == 47, 'SOC_REVISED_CODE'] = '47'
df5.loc[df5.SOC_REVISED_CODE == 35, 'SOC_REVISED_CODE'] = '35'
df5.loc[df5.SOC_REVISED_CODE == 49, 'SOC_REVISED_CODE'] = '49'
df5.loc[df5.SOC_REVISED_CODE == 53, 'SOC_REVISED_CODE'] = '53'
df5.loc[df5.SOC_REVISED_CODE == 39, 'SOC_REVISED_CODE'] = '39'
df5.loc[df5.SOC_REVISED_CODE == 31, 'SOC_REVISED_CODE'] = '31'
df5.loc[df5.SOC_REVISED_CODE == 33, 'SOC_REVISED_CODE'] = '33'
df5.loc[df5.SOC_REVISED_CODE == 37, 'SOC_REVISED_CODE'] = '37'

# %%
df5['SOC_REVISED_CODE'].unique()
# Out:
# array(['15', '13', '19', '29', '17', '25', '20', '51', '27', '23', '11',
#        '41', '43', '21', '45', '47', '35', '49', '53', '39', '31', '33',
#        '37', 16, 'SO', 40, 73, '50', '73', '75', 38, 18, 12, 46, 'AC',
#        'AI', 24, 71, '28', 36, 26, '79', 'EL', '40', 74, 10, 22, '71',
#        'CO'], dtype=object)

# %%
df5.to_excel('Preprocessed_Dataset.xlsx')

# %%
df5.to_csv('Preprocessed_Dataset.csv')
